# %% [markdown]
# # Tutorial 8 – Equity Screening & Stock Selection Case
# ## FINM3422 – Professional Equity Research Workflow
#
# **Estimated time:** ~2 hours (group-based)
#
# ---
#
# ### Scenario
#
# You are part of a junior **equity research team** at an asset management firm.
#
# Management has asked your team to:
#
# > **Screen a universe of NASDAQ-listed technology companies and recommend ONE stock**
# > for deeper fundamental analysis later in the course.
#
# This notebook is intentionally structured like a **professional research notebook**,
# following the modelling discipline discussed in **Lecture 6**.
#
# You will work **collaboratively** using GitHub feature branches and pull requests.

# %% [markdown]
# ## 1. Environment & Imports (≈5 minutes)
#
# Professional modelling always begins by making the computing environment explicit.
#
# Why this matters:
# - Reproducibility across machines
# - Clear collaboration in teams
# - Fewer hidden bugs caused by implicit state
#
# In this tutorial, we use **yfinance**, a free and stable Python library that provides
# programmatic access to Yahoo Finance data.
#
# No API key is required, which removes setup friction during tutorials.

# %%
# %pip install yfinance
# Out:
# Collecting yfinance
#   Downloading yfinance-1.3.0-py2.py3-none-any.whl.metadata (6.1 kB)
# Collecting pandas>=1.3.0 (from yfinance)
#   Downloading pandas-3.0.2-cp314-cp314-win_amd64.whl.metadata (19 kB)
# Collecting numpy>=1.16.5 (from yfinance)
#   Downloading numpy-2.4.4-cp314-cp314-win_amd64.whl.metadata (6.6 kB)
# Collecting requests>=2.31 (from yfinance)
#   Downloading requests-2.33.1-py3-none-any.whl.metadata (4.8 kB)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Downloading multitasking-0.0.13-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: platformdirs>=2.0.0 in .\.venv\Lib\site-packages (from yfinance) (4.9.6)
# Collecting pytz>=2022.5 (from yfinance)
#   Downloading pytz-2026.1.post1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting frozendict>=2.3.4 (from yfinance)
#   Downloading frozendict-2.4.7-py3-none-any.whl.metadata (23 kB)
# Collecting peewee>=3.16.2 (from yfinance)
#   Downloading peewee-4.0.5-py3-none-any.whl.metadata (8.6 kB)
# Collecting beautifulsoup4>=4.11.1 (from yfinance)
#   Downloading beautifulsoup4-4.14.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting curl_cffi>=0.15 (from yfinance)
#   Downloading curl_cffi-0.15.0-cp310-abi3-win_amd64.whl.metadata (18 kB)
# Collecting protobuf>=3.19.0 (from yfinance)
#   Downloading protobuf-7.34.1-cp310-abi3-win_amd64.whl.metadata (595 bytes)
# Collecting websockets>=13.0 (from yfinance)
#   Downloading websockets-16.0-cp314-cp314-win_amd64.whl.metadata (7.0 kB)
# Collecting soupsieve>=1.6.1 (from beautifulsoup4>=4.11.1->yfinance)
#   Downloading soupsieve-2.8.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting typing-extensions>=4.0.0 (from beautifulsoup4>=4.11.1->yfinance)
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting cffi>=2.0.0 (from curl_cffi>=0.15->yfinance)
#   Downloading cffi-2.0.0-cp314-cp314-win_amd64.whl.metadata (2.6 kB)
# Collecting certifi>=2024.2.2 (from curl_cffi>=0.15->yfinance)
#   Downloading certifi-2026.4.22-py3-none-any.whl.metadata (2.5 kB)
# Collecting rich (from curl_cffi>=0.15->yfinance)
#   Downloading rich-15.0.0-py3-none-any.whl.metadata (18 kB)
# Collecting pycparser (from cffi>=2.0.0->curl_cffi>=0.15->yfinance)
#   Downloading pycparser-3.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in .\.venv\Lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Collecting tzdata (from pandas>=1.3.0->yfinance)
#   Downloading tzdata-2026.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in .\.venv\Lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Collecting charset_normalizer<4,>=2 (from requests>=2.31->yfinance)
#   Downloading charset_normalizer-3.4.7-cp314-cp314-win_amd64.whl.metadata (41 kB)
# Collecting idna<4,>=2.5 (from requests>=2.31->yfinance)
#   Downloading idna-3.13-py3-none-any.whl.metadata (8.0 kB)
# Collecting urllib3<3,>=1.26 (from requests>=2.31->yfinance)
#   Downloading urllib3-2.6.3-py3-none-any.whl.metadata (6.9 kB)
# Collecting markdown-it-py>=2.2.0 (from rich->curl_cffi>=0.15->yfinance)
#   Downloading markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in .\.venv\Lib\site-packages (from rich->curl_cffi>=0.15->yfinance) (2.20.0)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->curl_cffi>=0.15->yfinance)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading yfinance-1.3.0-py2.py3-none-any.whl (133 kB)
# Downloading beautifulsoup4-4.14.3-py3-none-any.whl (107 kB)
# Downloading curl_cffi-0.15.0-cp310-abi3-win_amd64.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 1.7/1.7 MB 17.1 MB/s  0:00:00
# Downloading certifi-2026.4.22-py3-none-any.whl (135 kB)
# Downloading cffi-2.0.0-cp314-cp314-win_amd64.whl (185 kB)
# Downloading frozendict-2.4.7-py3-none-any.whl (16 kB)
# Downloading multitasking-0.0.13-py3-none-any.whl (16 kB)
# Downloading numpy-2.4.4-cp314-cp314-win_amd64.whl (12.4 MB)
#    ---------------------------------------- 0.0/12.4 MB ? eta -:--:--
#    ---------------- ----------------------- 5.0/12.4 MB 24.5 MB/s eta 0:00:01
#    ---------------------------------------  12.3/12.4 MB 30.4 MB/s eta 0:00:01
#    ---------------------------------------- 12.4/12.4 MB 28.6 MB/s  0:00:00
# Downloading pandas-3.0.2-cp314-cp314-win_amd64.whl (9.9 MB)
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    -------------------- ------------------- 5.0/9.9 MB 23.6 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 27.1 MB/s  0:00:00
# Downloading peewee-4.0.5-py3-none-any.whl (144 kB)
# Downloading protobuf-7.34.1-cp310-abi3-win_amd64.whl (437 kB)
# Downloading pytz-2026.1.post1-py2.py3-none-any.whl (510 kB)
# Downloading requests-2.33.1-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.7-cp314-cp314-win_amd64.whl (159 kB)
# Downloading idna-3.13-py3-none-any.whl (68 kB)
# Downloading urllib3-2.6.3-py3-none-any.whl (131 kB)
# Downloading soupsieve-2.8.3-py3-none-any.whl (37 kB)
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading websockets-16.0-cp314-cp314-win_amd64.whl (178 kB)
# Downloading pycparser-3.0-py3-none-any.whl (48 kB)
# Downloading rich-15.0.0-py3-none-any.whl (310 kB)
# Downloading markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading tzdata-2026.1-py2.py3-none-any.whl (348 kB)
# Installing collected packages: pytz, peewee, multitasking, websockets, urllib3, tzdata, typing-extensions, soupsieve, pycparser, protobuf, numpy, mdurl, idna, frozendict, charset_normalizer, certifi, requests, pandas, markdown-it-py, cffi, beautifulsoup4, rich, curl_cffi, yfinance
#
#    ----------------------------------------  0/24 [pytz]
#    ----------------------------------------  0/24 [pytz]
#    ----------------------------------------  0/24 [pytz]
#    - --------------------------------------  1/24 [peewee]
#    - --------------------------------------  1/24 [peewee]
#    ----- ----------------------------------  3/24 [websockets]
#    ----- ----------------------------------  3/24 [websockets]
#    ------ ---------------------------------  4/24 [urllib3]
#    -------- -------------------------------  5/24 [tzdata]
#    -------- -------------------------------  5/24 [tzdata]
#    -------- -------------------------------  5/24 [tzdata]
#    -------- -------------------------------  5/24 [tzdata]
#    -------- -------------------------------  5/24 [tzdata]
#    -------- -------------------------------  5/24 [tzdata]
#    ----------- ----------------------------  7/24 [soupsieve]
#    --------------- ------------------------  9/24 [protobuf]
#    --------------- ------------------------  9/24 [protobuf]
#    --------------- ------------------------  9/24 [protobuf]
#    ---------------- ----------------------- 10/24 [numpy]
#    ---------------- ----------------------- 10/24 [numpy]
#    ---------------- ----------------------- 10/24 [numpy]
#    ---------------- ----------------------- 10/24 [numpy]
#    ---------------- ----------------------- 10/24 [numpy]
#    ---------------- ----------------------- 10/24 [numpy]
#    ---------------- ----------------------- 10/24 [numpy]
#    ---------------- ----------------------- 10/24 [numpy]
#    ---------------- ----------------------- 10/24 [numpy]
#    ---------------- ----------------------- 10/24 [numpy]
#    ---------------- ----------------------- 10/24 [numpy]
#    ---------------- ----------------------- 10/24 [numpy]
#    ---------------- ----------------------- 10/24 [numpy]
#    ---------------- ----------------------- 10/24 [numpy]
#    ---------------- ----------------------- 10/24 [numpy]
#    ---------------- ----------------------- 10/24 [numpy]
#    ---------------- ----------------------- 10/24 [numpy]
#    ---------------- ----------------------- 10/24 [numpy]
#    ---------------- ----------------------- 10/24 [numpy]
#    ---------------- ----------------------- 10/24 [numpy]
#    ---------------- ----------------------- 10/24 [numpy]
#    ---------------- ----------------------- 10/24 [numpy]
#    ---------------- ----------------------- 10/24 [numpy]
#    ---------------- ----------------------- 10/24 [numpy]
#    ---------------- ----------------------- 10/24 [numpy]
#    ---------------- ----------------------- 10/24 [numpy]
#    ---------------- ----------------------- 10/24 [numpy]
#    ---------------- ----------------------- 10/24 [numpy]
#    ------------------ --------------------- 11/24 [mdurl]
#    -------------------- ------------------- 12/24 [idna]
#    ----------------------- ---------------- 14/24 [charset_normalizer]
#    ------------------------- -------------- 15/24 [certifi]
#    -------------------------- ------------- 16/24 [requests]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ------------------------------ --------- 18/24 [markdown-it-py]
#    ------------------------------ --------- 18/24 [markdown-it-py]
#    ------------------------------- -------- 19/24 [cffi]
#    --------------------------------- ------ 20/24 [beautifulsoup4]
#    ----------------------------------- ---- 21/24 [rich]
#    ----------------------------------- ---- 21/24 [rich]
#    ----------------------------------- ---- 21/24 [rich]
#    ----------------------------------- ---- 21/24 [rich]
#    ----------------------------------- ---- 21/24 [rich]
#    ------------------------------------ --- 22/24 [curl_cffi]
#    ------------------------------------ --- 22/24 [curl_cffi]
#    -------------------------------------- - 23/24 [yfinance]
#    -------------------------------------- - 23/24 [yfinance]
#    -------------------------------------- - 23/24 [yfinance]
#    ---------------------------------------- 24/24 [yfinance]
#
# Successfully installed beautifulsoup4-4.14.3 certifi-2026.4.22 cffi-2.0.0 charset_normalizer-3.4.7 curl_cffi-0.15.0 frozendict-2.4.7 idna-3.13 markdown-it-py-4.0.0 mdurl-0.1.2 multitasking-0.0.13 numpy-2.4.4 pandas-3.0.2 peewee-4.0.5 protobuf-7.34.1 pycparser-3.0 pytz-2026.1.post1 requests-2.33.1 rich-15.0.0 soupsieve-2.8.3 typing-extensions-4.15.0 tzdata-2026.1 urllib3-2.6.3 websockets-16.0 yfinance-1.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install yfinance
# Out:
# Requirement already satisfied: yfinance in .\.venv\Lib\site-packages (1.3.0)
# Requirement already satisfied: pandas>=1.3.0 in .\.venv\Lib\site-packages (from yfinance) (3.0.2)
# Requirement already satisfied: numpy>=1.16.5 in .\.venv\Lib\site-packages (from yfinance) (2.4.4)
# Requirement already satisfied: requests>=2.31 in .\.venv\Lib\site-packages (from yfinance) (2.33.1)
# Requirement already satisfied: multitasking>=0.0.7 in .\.venv\Lib\site-packages (from yfinance) (0.0.13)
# Requirement already satisfied: platformdirs>=2.0.0 in .\.venv\Lib\site-packages (from yfinance) (4.9.6)
# Requirement already satisfied: pytz>=2022.5 in .\.venv\Lib\site-packages (from yfinance) (2026.1.post1)
# Requirement already satisfied: frozendict>=2.3.4 in .\.venv\Lib\site-packages (from yfinance) (2.4.7)
# Requirement already satisfied: peewee>=3.16.2 in .\.venv\Lib\site-packages (from yfinance) (4.0.5)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in .\.venv\Lib\site-packages (from yfinance) (4.14.3)
# Requirement already satisfied: curl_cffi>=0.15 in .\.venv\Lib\site-packages (from yfinance) (0.15.0)
# Requirement already satisfied: protobuf>=3.19.0 in .\.venv\Lib\site-packages (from yfinance) (7.34.1)
# Requirement already satisfied: websockets>=13.0 in .\.venv\Lib\site-packages (from yfinance) (16.0)
# Requirement already satisfied: soupsieve>=1.6.1 in .\.venv\Lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in .\.venv\Lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.15.0)
# Requirement already satisfied: cffi>=2.0.0 in .\.venv\Lib\site-packages (from curl_cffi>=0.15->yfinance) (2.0.0)
# Requirement already satisfied: certifi>=2024.2.2 in .\.venv\Lib\site-packages (from curl_cffi>=0.15->yfinance) (2026.4.22)
# Requirement already satisfied: rich in .\.venv\Lib\site-packages (from curl_cffi>=0.15->yfinance) (15.0.0)
# Requirement already satisfied: pycparser in .\.venv\Lib\site-packages (from cffi>=2.0.0->curl_cffi>=0.15->yfinance) (3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in .\.venv\Lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata in .\.venv\Lib\site-packages (from pandas>=1.3.0->yfinance) (2026.1)
# Requirement already satisfied: six>=1.5 in .\.venv\Lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in .\.venv\Lib\site-packages (from requests>=2.31->yfinance) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in .\.venv\Lib\site-packages (from requests>=2.31->yfinance) (3.13)
# Requirement already satisfied: urllib3<3,>=1.26 in .\.venv\Lib\site-packages (from requests>=2.31->yfinance) (2.6.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in .\.venv\Lib\site-packages (from rich->curl_cffi>=0.15->yfinance) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in .\.venv\Lib\site-packages (from rich->curl_cffi>=0.15->yfinance) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in .\.venv\Lib\site-packages (from markdown-it-py>=2.2.0->rich->curl_cffi>=0.15->yfinance) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install yfinance
# Out:
# Requirement already satisfied: yfinance in .\.venv\Lib\site-packages (1.3.0)
# Requirement already satisfied: pandas>=1.3.0 in .\.venv\Lib\site-packages (from yfinance) (3.0.2)
# Requirement already satisfied: numpy>=1.16.5 in .\.venv\Lib\site-packages (from yfinance) (2.4.4)
# Requirement already satisfied: requests>=2.31 in .\.venv\Lib\site-packages (from yfinance) (2.33.1)
# Requirement already satisfied: multitasking>=0.0.7 in .\.venv\Lib\site-packages (from yfinance) (0.0.13)
# Requirement already satisfied: platformdirs>=2.0.0 in .\.venv\Lib\site-packages (from yfinance) (4.9.6)
# Requirement already satisfied: pytz>=2022.5 in .\.venv\Lib\site-packages (from yfinance) (2026.1.post1)
# Requirement already satisfied: frozendict>=2.3.4 in .\.venv\Lib\site-packages (from yfinance) (2.4.7)
# Requirement already satisfied: peewee>=3.16.2 in .\.venv\Lib\site-packages (from yfinance) (4.0.5)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in .\.venv\Lib\site-packages (from yfinance) (4.14.3)
# Requirement already satisfied: curl_cffi>=0.15 in .\.venv\Lib\site-packages (from yfinance) (0.15.0)
# Requirement already satisfied: protobuf>=3.19.0 in .\.venv\Lib\site-packages (from yfinance) (7.34.1)
# Requirement already satisfied: websockets>=13.0 in .\.venv\Lib\site-packages (from yfinance) (16.0)
# Requirement already satisfied: soupsieve>=1.6.1 in .\.venv\Lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in .\.venv\Lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.15.0)
# Requirement already satisfied: cffi>=2.0.0 in .\.venv\Lib\site-packages (from curl_cffi>=0.15->yfinance) (2.0.0)
# Requirement already satisfied: certifi>=2024.2.2 in .\.venv\Lib\site-packages (from curl_cffi>=0.15->yfinance) (2026.4.22)
# Requirement already satisfied: rich in .\.venv\Lib\site-packages (from curl_cffi>=0.15->yfinance) (15.0.0)
# Requirement already satisfied: pycparser in .\.venv\Lib\site-packages (from cffi>=2.0.0->curl_cffi>=0.15->yfinance) (3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in .\.venv\Lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata in .\.venv\Lib\site-packages (from pandas>=1.3.0->yfinance) (2026.1)
# Requirement already satisfied: six>=1.5 in .\.venv\Lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in .\.venv\Lib\site-packages (from requests>=2.31->yfinance) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in .\.venv\Lib\site-packages (from requests>=2.31->yfinance) (3.13)
# Requirement already satisfied: urllib3<3,>=1.26 in .\.venv\Lib\site-packages (from requests>=2.31->yfinance) (2.6.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in .\.venv\Lib\site-packages (from rich->curl_cffi>=0.15->yfinance) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in .\.venv\Lib\site-packages (from rich->curl_cffi>=0.15->yfinance) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in .\.venv\Lib\site-packages (from markdown-it-py>=2.2.0->rich->curl_cffi>=0.15->yfinance) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
# !{sys.executable} -m pip install yfinance
# Out:
# 'c:\Users\aceli\OneDrive' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import yfinance as yf
yf.Ticker("AAPL").history(period="1mo")
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2026-03-24 00:00:00-04:00  250.350006  254.830002  249.550003  251.639999
# 2026-03-25 00:00:00-04:00  254.100006  255.000000  251.600006  252.619995
# 2026-03-26 00:00:00-04:00  252.119995  257.000000  250.770004  252.889999
# 2026-03-27 00:00:00-04:00  253.899994  255.490005  248.070007  248.800003
# 2026-03-30 00:00:00-04:00  250.070007  250.869995  245.509995  246.630005
# 2026-03-31 00:00:00-04:00  247.910004  255.479996  247.100006  253.789993
# 2026-04-01 00:00:00-04:00  254.080002  256.179993  253.330002  255.630005
# 2026-04-02 00:00:00-04:00  254.199997  256.130005  250.649994  255.919998
# 2026-04-06 00:00:00-04:00  256.510010  262.160004  256.459991  258.859985
# 2026-04-07 00:00:00-04:00  256.160004  256.200012  245.699997  253.500000
# 2026-04-08 00:00:00-04:00  258.450012  259.750000  256.529999  258.899994
# 2026-04-09 00:00:00-04:00  259.000000  261.119995  256.070007  260.489990
# 2026-04-10 00:00:00-04:00  259.980011  262.190002  259.019989  260.480011
# 2026-04-13 00:00:00-04:00  259.730011  260.179993  256.660004  259.200012
# 2026-04-14 00:00:00-04:00  259.250000  261.929993  257.190002  258.829987
# 2026-04-15 00:00:00-04:00  258.160004  266.559998  257.809998  266.429993
# 2026-04-16 00:00:00-04:00  266.799988  267.160004  261.269989  263.399994
# 2026-04-17 00:00:00-04:00  266.959991  272.299988  266.720001  270.230011
# 2026-04-20 00:00:00-04:00  270.329987  274.279999  270.290009  273.049988
# 2026-04-21 00:00:00-04:00  271.500000  272.799988  265.399994  266.170013
# 2026-04-22 00:00:00-04:00  267.820007  273.739990  266.869995  273.170013
# 2026-04-23 00:00:00-04:00  275.045013  275.769989  271.649994  273.429993
#
#                              Volume  Dividends  Stock Splits
# Date
# 2026-03-24 00:00:00-04:00  45152300        0.0           0.0
# 2026-03-25 00:00:00-04:00  28476700        0.0           0.0
# 2026-03-26 00:00:00-04:00  41796700        0.0           0.0
# 2026-03-27 00:00:00-04:00  47900000        0.0           0.0
# 2026-03-30 00:00:00-04:00  39446200        0.0           0.0
# 2026-03-31 00:00:00-04:00  49598100        0.0           0.0
# 2026-04-01 00:00:00-04:00  40059400        0.0           0.0
# 2026-04-02 00:00:00-04:00  31289400        0.0           0.0
# 2026-04-06 00:00:00-04:00  29329900        0.0           0.0
# 2026-04-07 00:00:00-04:00  62148000        0.0           0.0
# 2026-04-08 00:00:00-04:00  41032800        0.0           0.0
# 2026-04-09 00:00:00-04:00  28121600        0.0           0.0
# 2026-04-10 00:00:00-04:00  31291500        0.0           0.0
# 2026-04-13 00:00:00-04:00  36234700        0.0           0.0
# 2026-04-14 00:00:00-04:00  48370700        0.0           0.0
# 2026-04-15 00:00:00-04:00  49913500        0.0           0.0
# 2026-04-16 00:00:00-04:00  43323100        0.0           0.0
# 2026-04-17 00:00:00-04:00  61436200        0.0           0.0
# 2026-04-20 00:00:00-04:00  36590200        0.0           0.0
# 2026-04-21 00:00:00-04:00  50209800        0.0           0.0
# 2026-04-22 00:00:00-04:00  43249200        0.0           0.0
# 2026-04-23 00:00:00-04:00  33138070        0.0           0.0

# %%
# If needed (run once): pip install yfinance in console or use %pip install yfinance in your notebook

import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

plt.style.use("seaborn-v0_8")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[19], line 6
#       2
#       3 import yfinance as yf
#       4 import pandas as pd
#       5 import numpy as np
# ----> 6 import matplotlib.pyplot as plt
#       7
#       8 plt.style.use("seaborn-v0_8")
#
# ModuleNotFoundError: No module named 'matplotlib'

# %% [markdown]
# ## What is the yfinance API?
#
# `yfinance` is a Python wrapper around Yahoo Finance endpoints.
# It allows analysts to retrieve:
#
# - historical price data (daily, weekly, monthly)
# - company metadata
# - financial statements (income statement, balance sheet, cash flow)
#
# It is:
# - ✅ free
# - ✅ fast to learn
# - ✅ widely used for research prototyping and teaching
#
# ⚠️ Important:
# `yfinance` is **not an institutional-grade data source** (e.g. Bloomberg or Refinitiv),
# but it is perfectly suitable for **learning professional modelling workflows**.

# %% [markdown]
# ## 2. Define the Investment Universe (≈5 minutes)
#
# Equity research always begins with a clearly defined **investment universe**.
#
# We restrict attention to a curated list of **large‑cap NASDAQ technology companies**.
#
# Using a fixed universe ensures:
# - Comparability across tutorial teams
# - Stable API behaviour in class
# - Focus on modelling rather than data hunting

# %%
tickers = [
    "AAPL",  # Apple
    "MSFT",  # Microsoft
    "NVDA",  # Nvidia
    "ADBE",  # Adobe
    "META",  # Meta Platforms
    "CRM",   # Salesforce
    "ORCL",  # Oracle
    "NOW",   # ServiceNow
    "INTU",  # Intuit
    "AMD"    # Advanced Micro Devices
]

# %% [markdown]
# ## 3. Price Data Ingestion – API → DataFrame (≈15 minutes)
#
# In professional workflows, analysts **do not manually download CSV files**.
# Instead, data is pulled programmatically via APIs.
#
# The main function used by yfinance is:
#
#     yf.download()
#
# ### Key parameters you must understand
#
# - `tickers`
#   A single ticker (string) or multiple tickers (list)
#
# - `interval`
#   Controls **frequency** of observations
#   Examples:
#   - `"1d"`  → daily data
#   - `"1wk"` → weekly data
#   - `"1mo"` → monthly data
#
# - `period`
#   Controls **how much history** is returned
#   Examples:
#   - `"1y"`   → last year
#   - `"5y"`   → last 5 years
#   - `"max"`  → full available history
#
# ⚠️ **Critical rule**
# > Never rely on API defaults. Always specify `period` explicitly.

# %% [markdown]
# ## Why We Use Monthly Data in This Tutorial
#
# In FINM3422:
# - portfolio returns are monthly
# - performance metrics are monthly
# - Assignment 2 uses monthly frequency
#
# Therefore, we deliberately request:
# - `interval = "1mo"` → monthly observations
# - `period = "max"`   → long historical window
#
# This ensures:
# - frequency is correct before computing returns
# - enough observations exist for rolling metrics
# - alignment with Lecture 6 modelling discipline

# %%
# TODO:
# Use yf.download to retrieve monthly adjusted prices
# - interval="1mo"
# - period="max"
# - auto_adjust=True
# Then:
# - keep adjusted close prices
# - ensure DatetimeIndex
# - sort index

# %% [markdown]
# ## 4. Data Inspection & Sanity Checks (≈10 minutes)
#
# Before computing metrics, analysts **inspect the raw data**.
#
# You should check:
# - `.info()`
# - missing values (`.isna().sum()`)
# - index type (`type(df.index)`)
# - chronological ordering
#
# ### Important modelling principle (Lecture 6)
#
# > NA does **not** mean bad data.
# > It often means the company did not exist yet (IPO timing).
#
# Different firms have different listing dates.
# This is **economically correct**, not an error.

# %%
# TODO:
# Inspect the price DataFrame:
# - info()
# - missing values
# - index properties

# %% [markdown]
# ## 5. Returns & Performance Metrics (≈15 minutes)
#
# Equity screeners often include **recent market performance**
# (e.g. momentum or confirmation).
#
# Tasks:
# - Compute monthly returns
# - Compute trailing 12‑month total return
#
# ⚠️ Always fix frequency *before* computing returns.

# %%
# TODO:
# 1. Compute monthly returns using pct_change()
# 2. Compute trailing 12‑month total return

# %% [markdown]
# ## 6. Visual Diagnostics – Wealth Index (≈15 minutes)
#
# Before trusting any metric, professional analysts **plot a wealth index**.
#
# A wealth index answers:
# > What happens to $1 invested over time?
#
# This diagnostic reveals:
# - missing months
# - compounding errors
# - extreme outliers dominating results

# %%
# TODO:
# Construct and plot wealth indices
# Plot at least 3 stocks
# Add a brief interpretation

# %% [markdown]
# ## 7. Fundamental Indicators – Growth & Quality (≈20 minutes)
#
# Market prices alone are not sufficient for equity analysis.
#
# We complement price performance with **fundamentals**.
#
# Two indicators:
# - **Revenue growth** (latest year vs previous year)
# - **Operating margin** (operating income / revenue)
#
# Financial statements are accessed using:
#
#     yf.Ticker("AAPL").financials

# %%
# TODO:
# For each ticker:
# - retrieve financial statements using yf.Ticker
# - compute revenue growth
# - compute operating margin
# Store results in a DataFrame

# %% [markdown]
# ## 8. Screening Table Construction (≈15 minutes)
#
# Professional screeners combine **all signals into one master table**.
#
# Structure:
# - each row → one stock
# - each column → one screening signal
#
# This table forms the basis for ranking and decision‑making.

# %%
# TODO:
# Combine:
# - 12‑month return
# - revenue growth
# - operating margin
# into a single screening table

# %% [markdown]
# ## 9. Ranking & Shortlisting Logic (≈15 minutes)
#
# Equity screening is about **narrowing the universe**, not precision.
#
# Rank stocks using:
# - revenue growth
# - operating margin
# - 12‑month performance
#
# Combine ranks into a **composite score**.
#
# There is no single correct answer —
# only defensible logic that can be explained.

# %%
# TODO:
# Rank each metric
# Compute composite score
# Sort stocks from most to least attractive

# %% [markdown]
# ## 10. Stock Selection – Analyst Decision (≈10 minutes)
#
# Your team must now make a **judgement call**.
#
# Select **ONE stock** to recommend for deeper analysis.
#
# Write as if presenting to an **investment committee**.

# %%
### Selected Stock

### Analyst Rationale
- Growth outlook:
- Profitability / quality:
- Market performance:
- Key risks:

# %% [markdown]
# ## 11. GitHub Collaboration Reflection (≈10 minutes)
#
# Equity research is a **team activity**.
#
# Document:
# - Who worked on which sections
# - How feature branches and pull requests were used
# - Any challenges encountered

# %% [markdown]
# - Member A:
# - Member B:
# - Member C:
